# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('NumreicalValues_Season3 - Sheet1.csv')

# %%
data
# Out:
#       RHR    HRV  Recovery  Sleep.Score  Hours.in.Bed  Hours.of.Sleep  \
# 0     NaN    NaN       NaN          NaN           NaN             NaN
# 1     NaN    NaN       NaN          NaN           NaN             NaN
# 2     NaN    NaN       NaN          NaN           NaN             NaN
# 3     NaN    NaN       NaN          NaN           NaN             NaN
# 4     NaN    NaN       NaN          NaN           NaN             NaN
# ..    ...    ...       ...          ...           ...             ...
# 237  43.0  167.0      81.0         72.0          7.17            6.82
# 238   NaN    NaN       NaN          NaN           NaN             NaN
# 239  60.0  105.0      61.0         60.0          5.09            4.72
# 240  59.0  129.0      84.0        100.0          8.57            7.85
# 241  56.0   78.0      53.0         78.0          8.15            7.08
#
#      Sleep.Need  Sleep.Efficiency....  Wake.Periods  Sleep.Disturbances  ...  \
# 0           NaN                   NaN           NaN                 NaN  ...
# 1           NaN                   NaN           NaN                 NaN  ...
# 2           NaN                   NaN           NaN                 NaN  ...
# 3           NaN                   NaN           NaN                 NaN  ...
# 4           NaN                   NaN           NaN                 NaN  ...
# ..          ...                   ...           ...                 ...  ...
# 237        9.50                  95.0           9.0                 8.0  ...
# 238         NaN                   NaN           NaN                 NaN  ...
# 239        7.81                  93.0           NaN                 9.0  ...
# 240        7.70                  92.0          13.0                11.0  ...
# 241        9.12                  87.0          18.0                14.0  ...
#
#      Recovery.time..h.  Calories..kcal.  \
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ..                 ...              ...
# 237              316.0            224.0
# 238                NaN              NaN
# 239              256.0            233.0
# 240              145.0            128.0
# 241              112.0             98.0
#
#      Number.of.accelerations...50.00....3.00.m.s².  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 237                                          266.0
# 238                                            NaN
# 239                                          247.0
# 240                                          163.0
# 241                                           97.0
#
#      Number.of.accelerations...2.99....2.00.m.s².  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 237                                         287.0
# 238                                           NaN
# 239                                         251.0
# 240                                         136.0
# 241                                         106.0
#
#      Number.of.accelerations...1.99....1.00.m.s².  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 237                                          51.0
# 238                                           NaN
# 239                                          56.0
# 240                                          30.0
# 241                                          21.0
#
#      Number.of.accelerations...0.99....0.50.m.s².  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 237                                         635.0
# 238                                           NaN
# 239                                         881.0
# 240                                         553.0
# 241                                         386.0
#
#      Number.of.accelerations..0.50...0.99.m.s².  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 237                                        91.0
# 238                                         NaN
# 239                                       187.0
# 240                                        74.0
# 241                                        69.0
#
#      Number.of.accelerations..1.00...1.99.m.s².  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 237                                       111.0
# 238                                         NaN
# 239                                       206.0
# 240                                        89.0
# 241                                        75.0
#
#      Number.of.accelerations..2.00...2.99.m.s².  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 237                                         9.9
# 238                                         NaN
# 239                                        60.4
# 240                                         7.2
# 241                                         6.6
#
#      Number.of.accelerations..3.00...50.00.m.s².
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 237                                          0.0
# 238                                          NaN
# 239                                          2.0
# 240                                          0.0
# 241                                          0.0
#
# [242 rows x 70 columns]

# %%
print(columns_to_impute)
# Out:
# ['RHR', 'HRV', 'Recovery', 'Sleep.Score', 'Hours.in.Bed', 'Hours.of.Sleep', 'Sleep.Need', 'Sleep.Efficiency....', 'Wake.Periods', 'Sleep.Disturbances', 'Latency..min.', 'Cycles', 'REM.Sleep..hours.', 'Deep.Sleep..hours.', 'Light.Sleep..hours.', 'Awake..hours.', 'Sleep.Debt..hours.', 'Sleep.Consistency', 'Respiratory.Rate', 'Total.Cycle.Sleep.Time..hours.', 'REM.Percentage', 'Deep.Sleep.Percentage', 'Restorative.Sleep..hours.', 'Restorative.Sleep....', 'PPC', 'MPC', 'EB', 'OR', 'MS', 'LA', 'NES', 'OS', 'Body.Weight..kg.', 'Peak.Power.Mean', 'Peak.Power.SD', 'Peak.Power.CoV', 'Peak.Power.BM.Mean', 'Peak.Power.BM.SD', 'Peak.Power.BM.CoV', 'RSI.Mean', 'RSI.SD', 'RSI.CoV', 'Jump.Height.Mean', 'Jump.Height.SD', 'Jump.Height.CoV', 'Week.Trimp.Total', 'Daily.Average', 'Weekly.SD', 'Monotony', 'Strain', 'RT.Volume.Load', 'HR.min..bpm.', 'HR.avg..bpm.', 'HR.max..bpm.', 'HR.min....', 'HR.avg....', 'HR.max....', 'Distance...min..m.min.', 'Maximum.speed..km.h.', 'Average.speed..km.h.', 'Sprints', 'Distance.in.Speed.zone.1..m...1.00...4.99.km.h.', 'Distance.in.Speed.zone.2..m...5.00...6.99.km.h.', 'Distance.in.Speed.zone.3..m...7.00...10.99.km.h.', 'Distance.in.Speed.zone.4..m...11.00...14.99.km.h.', 'Distance.in.Speed.zone.5..m...15.00..km.h.', 'Number.of.accelerations...50.00....3.00.m.s².', 'Number.of.accelerations...2.99....2.00.m.s².', 'Number.of.accelerations...1.99....1.00.m.s².', 'Number.of.accelerations...0.99....0.50.m.s².', 'Number.of.accelerations..0.50...0.99.m.s².', 'Number.of.accelerations..1.00...1.99.m.s².', 'Number.of.accelerations..2.00...2.99.m.s².', 'Number.of.accelerations..3.00...50.00.m.s².', 'Calories..kcal.', 'Training.load.score', 'Cardio.load', 'Recovery.time..h.']

# %%
columns_to_impute =  [
    'RHR', 'HRV', 'Recovery', 'Sleep.Score', 'Hours.in.Bed', 'Hours.of.Sleep', 'Sleep.Need',
    'Sleep.Efficiency....', 'Wake.Periods', 'Sleep.Disturbances', 'Latency..min.', 'Cycles',
    'REM.Sleep..hours.', 'Deep.Sleep..hours.', 'Light.Sleep..hours.', 'Awake..hours.', 'Sleep.Debt..hours.',
    'Sleep.Consistency', 'Respiratory.Rate', 'Total.Cycle.Sleep.Time..hours.', 'REM.Percentage',
    'Deep.Sleep.Percentage', 'Restorative.Sleep..hours.', 'Restorative.Sleep....', 'PPC', 'MPC', 'EB', 'OR', 'MS',
    'LA', 'NES', 'OS', 'Body.Weight..kg.', 'Peak.Power.Mean', 'Peak.Power.SD', 'Peak.Power.CoV', 'Peak.Power.BM.Mean',
    'Peak.Power.BM.SD', 'Peak.Power.BM.CoV', 'RSI.Mean', 'RSI.SD', 'RSI.CoV', 'Jump.Height.Mean', 'Jump.Height.SD',
    'Jump.Height.CoV', 'Week.Trimp.Total', 'Daily.Average', 'Weekly.SD', 'Monotony', 'Strain', 'RT.Volume.Load',
    'HR.min..bpm.', 'HR.avg..bpm.', 'HR.max..bpm.', 'HR.min....', 'HR.avg....', 'HR.max....',
    'Distance...min..m.min.', 'Maximum.speed..km.h.', 'Average.speed..km.h.', 'Sprints',
    'Distance.in.Speed.zone.1..m...1.00...4.99.km.h.', 'Distance.in.Speed.zone.2..m...5.00...6.99.km.h.',
    'Distance.in.Speed.zone.3..m...7.00...10.99.km.h.', 'Distance.in.Speed.zone.4..m...11.00...14.99.km.h.',
    'Distance.in.Speed.zone.5..m...15.00..km.h.', 'Number.of.accelerations...50.00....3.00.m.s².',
    'Number.of.accelerations...2.99....2.00.m.s².', 'Number.of.accelerations...1.99....1.00.m.s².',
    'Number.of.accelerations...0.99....0.50.m.s².', 'Number.of.accelerations..0.50...0.99.m.s².',
    'Number.of.accelerations..1.00...1.99.m.s².', 'Number.of.accelerations..2.00...2.99.m.s².',
    'Number.of.accelerations..3.00...50.00.m.s².', 'Calories..kcal.', 'Training.load.score', 'Cardio.load',
    'Recovery.time..h.'
]

# %%
missing_data = data[data.isnull().any(axis=1)]

# %%
for index, row in missing_data.iterrows():
    similar_row = data.dropna().sample(1)  # Select a random similar observation
    data.loc[index] = similar_row.values  # Replace missing values with values from similar observation

# %%
data.to_csv('imputed_data_season3.csv', index=False)
