# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df = pd.read_csv('/content/Numerical valuesSeason 2 - Sheet1.csv')

# %%
mice_imputer = IterativeImputer()

# Fit the imputer to your data
mice_imputer.fit(df)

# Perform imputation
imputed_data = mice_imputer.transform(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_iterative.py:785: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
df_imputed = pd.DataFrame(imputed_data, columns=df.columns)

# Save the imputed DataFrame to a CSV file
df_imputed.to_csv('imputed_dataset.csv', index=False)

# %%
df_imputed.head(10)
# Out:
#          RHR         HRV   Recovery  Sleep.Score  Hours.in.Bed  \
# 0  46.000000  133.000000  72.000000    64.000000      6.210000
# 1  55.000000  127.000000  96.000000    82.000000      7.890000
# 2  72.000000   79.000000  32.000000    71.000000      6.100000
# 3  46.000000  107.000000  91.000000   100.000000      5.820000
# 4  56.126202   91.576730  71.636919    88.098520      7.510286
# 5  57.961210   90.264192  67.039548    76.721079      7.527249
# 6  57.000000   95.000000  97.000000   100.000000      9.950000
# 7  52.000000   30.000000  37.000000    74.000000      6.860000
# 8  57.992312   92.317740  71.351100    82.905107      7.516719
# 9  59.000000  112.000000  66.000000    66.000000      6.790000
#
#    Hours.of.Sleep  Sleep.Need  Sleep.Efficiency....  Wake.Periods  \
# 0        5.950000    9.260000             96.000000      5.000000
# 1        7.290000    8.850000             92.000000     12.807711
# 2        5.380000    7.550000             88.000000     19.000000
# ...
